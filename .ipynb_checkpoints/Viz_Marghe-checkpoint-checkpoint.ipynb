# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

path = 'C:/Users/meggh/Documents/GitHub/'

rhz_artworks = pd.read_pickle(path+'Rhizome_data/rhizome_artworks_extra.pkl')
rhz_artists = pd.read_pickle(path+'Rhizome_data/rhizome_artists_extra.pkl')
moma_artists = pd.read_pickle(path+'MOMA_data/pickle/MoMAartists.pkl')
moma_artworks = pd.read_pickle(path+'MOMA_data/pickle/new_artworks.pkl')
moma_arch_des = pd.read_pickle(path+'MOMA_data/pickle/architecture_design_cont.pkl')
moma_old=  pd.read_pickle(path+'MOMA_data/pickle/old_artworks.pkl')
moma_new=  pd.read_pickle(path+'MOMA_data/pickle/new_artworks.pkl')

# %%
rhizome_male_artworks = rhz_artworks.loc[rhz_artworks['Gender'] == 'M']
rhizome_male_artworks = rhizome_male_artworks['dateAcquired'].value_counts().rename_axis('Date Acquired').reset_index(name='Male Artists')
rhizome_female_artworks = rhz_artworks.loc[rhz_artworks['Gender'] == 'F']
rhizome_female_artworks = rhizome_female_artworks['dateAcquired'].value_counts().rename_axis('Date Acquired').reset_index(name='Female Artists') 
rhizome_gender_artworks = pd.merge(rhizome_male_artworks, rhizome_female_artworks, left_on='Date Acquired', right_on='Date Acquired')
rhizome_gender_artworks = rhizome_gender_artworks.sort_values(by='Date Acquired')

rhizome_gender_artworks
# Out:
#    Date Acquired  Male Artists  Female Artists
# 8              0            77               9
# 15          2000             4               4
# 4           2001           163              70
# 3           2002           165              72
# 6           2003           103              24
# 2           2004           167              76
# 1           2005           173              63
# 5           2006           146              55
# 0           2007           180              84
# 7           2008            91              31
# 9           2009            61               7
# 12          2010            19               1
# 11          2011            30              13
# 10          2012            52              11
# 13          2013             9               1
# 16          2015             1               4
# 14          2021             7               7

# %%
plt.figure(figsize=(15,8))
ax = rhizome_gender_artworks.plot(x="Date Acquired", y="Male Artists", legend=False)
ax2 = ax.twinx()
rhizome_gender_artworks.plot(x="Date Acquired", y="Female Artists", ax=ax2, legend=False, color="r")
ax.figure.legend()
plt.show()

# %%
test = rhz_artworks['dateAcquired'].value_counts().rename_axis('year').reset_index(name='counts')
test = test.sort_values(by='year', ascending=True)

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=test, x="year", y="counts")
# Out:
# <AxesSubplot:xlabel='year', ylabel='counts'>

# %%
rhz_artworks['Gender'].value_counts()
# Out:
# M                                           1448
# F                                            533
# missing                                      156
# F, M                                          46
# M, M                                          29
# M, F                                          27
# M, M, M                                        6
# M, F, M                                        6
# F, F                                           5
# F, M, M                                        3
# N/B                                            2
# F, missing                                     2
# missing, M, F, F, F                            1
# missing, M                                     1
# F, F, F                                        1
# missing, F                                     1
# M, M, missing                                  1
# F, M, M, M, M, F, missing, M, missing, M       1
# M, F, F, M, M, M, M                            1
# Name: Gender, dtype: int64

# %%
moma_artworks
# Out:
#                                                    Title  \
# 0      City of Music, National Superior Conservatory ...
# 1      The Manhattan Transcripts Project, New York, N...
# 2      The Manhattan Transcripts Project, New York, N...
# 3      The Manhattan Transcripts Project, New York, N...
# 4      The Manhattan Transcripts Project, New York, N...
# ...                                                  ...
# 34149                                 Cóctel (Cocktail)
# 34150                                 Cóctel (Cocktail)
# 34151                                 Cóctel (Cocktail)
# 34152                                 Cóctel (Cocktail)
# 34153                                     May's Blue Eye
#
#                          Artist      ID  DateCreated  \
# 0      Christian de Portzamparc    7470         1987
# 1               Bernard Tschumi    7056         1980
# 2               Bernard Tschumi    7056         1980
# 3               Bernard Tschumi    7056         1980
# 4               Bernard Tschumi    7056         1980
# ...                         ...     ...          ...
# 34149       Alejandro Kuropatwa  132939         1996
# 34150       Alejandro Kuropatwa  132939         1996
# 34151       Alejandro Kuropatwa  132939         1996
# 34152       Alejandro Kuropatwa  132939         1996
# 34153           Farah Al Qasimi  131770         2020
#
#                                                   Medium  \
# 0                      Paint and colored pencil on print
# 1      Photographic reproduction with colored synthet...
# 2      Photographic reproduction with colored synthet...
# 3      Photographic reproduction with colored synthet...
# 4                                   Ink on tracing paper
# ...                                                  ...
# 34149                            Chromogenic color print
# 34150                            Chromogenic color print
# 34151                            Chromogenic color print
# 34152                            Chromogenic color print
# 34153                             Pigmented inkjet print
#
#                   Department DateAcquired  \
# 0      Architecture & Design   1995-01-17
# 1      Architecture & Design   1995-01-17
# 2      Architecture & Design   1995-01-17
# 3      Architecture & Design   1995-01-17
# 4      Architecture & Design   1995-01-17
# ...                      ...          ...
# 34149            Photography   2020-10-07
# 34150            Photography   2020-10-07
# 34151            Photography   2020-10-07
# 34152            Photography   2020-10-07
# 34153            Photography   2020-10-07
#
#                                            URL  \
# 0       http://www.moma.org/collection/works/3
# 1       http://www.moma.org/collection/works/5
# 2      http://www.moma.org/collection/works/33
# 3      http://www.moma.org/collection/works/38
# 4      http://www.moma.org/collection/works/44
# ...                                        ...
# 34149                                  missing
# 34150                                  missing
# 34151                                  missing
# 34152                                  missing
# 34153                                  missing
#
#                                             ThumbnailURL
# 0      http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...
# 1      http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...
# 2      http://www.moma.org/media/W1siZiIsIjIwMCJdLFsi...
# 3      http://www.moma.org/media/W1siZiIsIjI2NyJdLFsi...
# 4      http://www.moma.org/media/W1siZiIsIjI5NiJdLFsi...
# ...                                                  ...
# 34149                                            missing
# 34150                                            missing
# 34151                                            missing
# 34152                                            missing
# 34153                                            missing
#
# [34154 rows x 9 columns]

# %%
#count occurrences of date of acquisition values MOMA
test1 = moma_artworks['DateAcquired'].value_counts().rename_axis('year').reset_index(name='counts')
test1 = test.sort_values(by='year', ascending=True)

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=test1, x="year", y="counts")
# Out:
# <AxesSubplot:xlabel='year', ylabel='counts'>

# %%
#count occurrences of date of creation values MOMA
test2 = moma_artworks['DateCreated'].value_counts().rename_axis('year').reset_index(name='counts')
test2 = test.sort_values(by='year', ascending=True)

# %%
plt.figure(figsize=(15,8))
sns.lineplot(data=test2, x="year", y="counts")
# Out:
# <AxesSubplot:xlabel='year', ylabel='counts'>

# %%
moma_before
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       Villa near Vienna Project, Outside Vienna, Aus...
# 2       Villa, project, outside Vienna, Austria, Exter...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       The Manhattan Transcripts Project, New York, N...
# ...                                                   ...
# 100687                                           Untitled
# 100688  Plate (folio 2 verso) from Muscheln und schirm...
# 100689  Plate (folio 6) from Muscheln und schirme (She...
# 100690  Plate (folio 12) from Muscheln und schirme (Sh...
# 100691  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                              Emil Hoppe
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                         Bernard Tschumi
# ...                                                   ...
# 100687  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 100688                                 Sophie Taeuber-Arp
# 100689                                 Sophie Taeuber-Arp
# 100690                                 Sophie Taeuber-Arp
# 100691                                 Sophie Taeuber-Arp
#
#                             ID  DateCreated  \
# 0                         6210         1896
# 1                         7605         1903
# 2                         7605         1903
# 3                         7056         1976
# 4                         7056         1976
# ...                        ...          ...
# 100687  133005, 133006, 133007         1890
# 100688                    5777         1939
# 100689                    5777         1939
# 100690                    5777         1939
# 100691                    5777         1939
#
#                                                    Medium  \
# 0           Ink and cut-and-pasted painted pages on paper
# 1       Graphite, pen, color pencil, ink, and gouache ...
# 2       Graphite, color pencil, ink, and gouache on tr...
# 3                               Gelatin silver photograph
# 4                              Gelatin silver photographs
# ...                                                   ...
# 100687                               Gelatin silver print
# 100688  One from an illustrated book with four line bl...
# 100689  One from an illustrated book with four line bl...
# 100690  One from an illustrated book with four line bl...
# 100691  One from an illustrated book with four line bl...
#
#                    Department DateAcquired  \
# 0       Architecture & Design   1996-04-09
# 1       Architecture & Design   1997-01-15
# 2       Architecture & Design   1997-01-15
# 3       Architecture & Design   1995-01-17
# 4       Architecture & Design   1995-01-17
# ...                       ...          ...
# 100687            Photography   2020-10-07
# 100688      Drawings & Prints   2019-12-11
# 100689      Drawings & Prints   2019-12-11
# 100690      Drawings & Prints   2019-12-11
# 100691      Drawings & Prints   2019-12-11
#
#                                                 URL  \
# 0            http://www.moma.org/collection/works/2
# 1            http://www.moma.org/collection/works/4
# 2            http://www.moma.org/collection/works/6
# 3            http://www.moma.org/collection/works/7
# 4            http://www.moma.org/collection/works/8
# ...                                             ...
# 100687  http://www.moma.org/collection/works/418928
# 100688  http://www.moma.org/collection/works/419286
# 100689  http://www.moma.org/collection/works/419287
# 100690  http://www.moma.org/collection/works/419288
# 100691  http://www.moma.org/collection/works/419289
#
#                                              ThumbnailURL
# 0       http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...
# 1       http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...
# 2       http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...
# 3       http://www.moma.org/media/W1siZiIsIjE0OCJdLFsi...
# 4       http://www.moma.org/media/W1siZiIsIjE0OSJdLFsi...
# ...                                                   ...
# 100687  http://www.moma.org/media/W1siZiIsIjQ5MjcyMiJd...
# 100688  http://www.moma.org/media/W1siZiIsIjQ4NTExNSJd...
# 100689  http://www.moma.org/media/W1siZiIsIjQ4NTExOCJd...
# 100690  http://www.moma.org/media/W1siZiIsIjQ4NTEyMCJd...
# 100691  http://www.moma.org/media/W1siZiIsIjQ4NTEyMSJd...
#
# [100692 rows x 9 columns]

# %%
#number of artworks in moma before and after 1980 (old vs new)
moma_before= pd.DataFrame(moma_old)
moma_before['1980'] = 'before'

moma_after= pd.DataFrame(moma_new)
moma_after['1980'] = 'after'
# Out:
#                                                     Title  \
# 0       Ferdinandsbrücke Project, Vienna, Austria (Ele...
# 1       Villa near Vienna Project, Outside Vienna, Aus...
# 2       Villa, project, outside Vienna, Austria, Exter...
# 3       The Manhattan Transcripts Project, New York, N...
# 4       The Manhattan Transcripts Project, New York, N...
# ...                                                   ...
# 100687                                           Untitled
# 100688  Plate (folio 2 verso) from Muscheln und schirm...
# 100689  Plate (folio 6) from Muscheln und schirme (She...
# 100690  Plate (folio 12) from Muscheln und schirme (Sh...
# 100691  Plate (folio 16) from Muscheln und schirme (Sh...
#
#                                                    Artist  \
# 0                                             Otto Wagner
# 1                                              Emil Hoppe
# 2                                              Emil Hoppe
# 3                                         Bernard Tschumi
# 4                                         Bernard Tschumi
# ...                                                   ...
# 100687  Chesnutt Brothers Studio, Andrew Chesnutt, Lew...
# 100688                                 Sophie Taeuber-Arp
# 100689                                 Sophie Taeuber-Arp
# 100690                                 Sophie Taeuber-Arp
# 100691                                 Sophie Taeuber-Arp
#
#                             ID  DateCreated  \
# 0                         6210         1896
# 1                         7605         1903
# 2                         7605         1903
# 3                         7056         1976
# 4                         7056         1976
# ...                        ...          ...
# 100687  133005, 133006, 133007         1890
# 100688                    5777         1939
# 100689                    5777         1939
# 100690                    5777         1939
# 100691                    5777         1939
#
#                                                    Medium  \
# 0           Ink and cut-and-pasted painted pages on paper
# 1       Graphite, pen, color pencil, ink, and gouache ...
# 2       Graphite, color pencil, ink, and gouache on tr...
# 3                               Gelatin silver photograph
# 4                              Gelatin silver photographs
# ...                                                   ...
# 100687                               Gelatin silver print
# 100688  One from an illustrated book with four line bl...
# 100689  One from an illustrated book with four line bl...
# 100690  One from an illustrated book with four line bl...
# 100691  One from an illustrated book with four line bl...
#
#                    Department DateAcquired  \
# 0       Architecture & Design   1996-04-09
# 1       Architecture & Design   1997-01-15
# 2       Architecture & Design   1997-01-15
# 3       Architecture & Design   1995-01-17
# 4       Architecture & Design   1995-01-17
# ...                       ...          ...
# 100687            Photography   2020-10-07
# 100688      Drawings & Prints   2019-12-11
# 100689      Drawings & Prints   2019-12-11
# 100690      Drawings & Prints   2019-12-11
# 100691      Drawings & Prints   2019-12-11
#
#                                                 URL  \
# 0            http://www.moma.org/collection/works/2
# 1            http://www.moma.org/collection/works/4
# 2            http://www.moma.org/collection/works/6
# 3            http://www.moma.org/collection/works/7
# 4            http://www.moma.org/collection/works/8
# ...                                             ...
# 100687  http://www.moma.org/collection/works/418928
# 100688  http://www.moma.org/collection/works/419286
# 100689  http://www.moma.org/collection/works/419287
# 100690  http://www.moma.org/collection/works/419288
# 100691  http://www.moma.org/collection/works/419289
#
#                                              ThumbnailURL    1980
# 0       http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...  before
# 1       http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...  before
# 2       http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...  before
# 3       http://www.moma.org/media/W1siZiIsIjE0OCJdLFsi...  before
# 4       http://www.moma.org/media/W1siZiIsIjE0OSJdLFsi...  before
# ...                                                   ...     ...
# 100687  http://www.moma.org/media/W1siZiIsIjQ5MjcyMiJd...  before
# 100688  http://www.moma.org/media/W1siZiIsIjQ4NTExNSJd...  before
# 100689  http://www.moma.org/media/W1siZiIsIjQ4NTExOCJd...  before
# 100690  http://www.moma.org/media/W1siZiIsIjQ4NTEyMCJd...  before
# 100691  http://www.moma.org/media/W1siZiIsIjQ4NTEyMSJd...  before
#
# [100692 rows x 10 columns]

# %%
frames = [moma_before, moma_after]


moma_artworks_two_periods = pd.concat(frames)
moma_artworks_two_periods
# Out:
#                                                    Title               Artist  \
# 0      Ferdinandsbrücke Project, Vienna, Austria (Ele...          Otto Wagner
# 1      Villa near Vienna Project, Outside Vienna, Aus...           Emil Hoppe
# 2      Villa, project, outside Vienna, Austria, Exter...           Emil Hoppe
# 3      The Manhattan Transcripts Project, New York, N...      Bernard Tschumi
# 4      The Manhattan Transcripts Project, New York, N...      Bernard Tschumi
# ...                                                  ...                  ...
# 34149                                 Cóctel (Cocktail)  Alejandro Kuropatwa
# 34150                                 Cóctel (Cocktail)  Alejandro Kuropatwa
# 34151                                 Cóctel (Cocktail)  Alejandro Kuropatwa
# 34152                                 Cóctel (Cocktail)  Alejandro Kuropatwa
# 34153                                     May's Blue Eye      Farah Al Qasimi
#
#            ID  DateCreated                                             Medium  \
# 0        6210         1896      Ink and cut-and-pasted painted pages on paper
# 1        7605         1903  Graphite, pen, color pencil, ink, and gouache ...
# 2        7605         1903  Graphite, color pencil, ink, and gouache on tr...
# 3        7056         1976                          Gelatin silver photograph
# 4        7056         1976                         Gelatin silver photographs
# ...       ...          ...                                                ...
# 34149  132939         1996                            Chromogenic color print
# 34150  132939         1996                            Chromogenic color print
# 34151  132939         1996                            Chromogenic color print
# 34152  132939         1996                            Chromogenic color print
# 34153  131770         2020                             Pigmented inkjet print
#
#                   Department DateAcquired  \
# 0      Architecture & Design   1996-04-09
# 1      Architecture & Design   1997-01-15
# 2      Architecture & Design   1997-01-15
# 3      Architecture & Design   1995-01-17
# 4      Architecture & Design   1995-01-17
# ...                      ...          ...
# 34149            Photography   2020-10-07
# 34150            Photography   2020-10-07
# 34151            Photography   2020-10-07
# 34152            Photography   2020-10-07
# 34153            Photography   2020-10-07
#
#                                           URL  \
# 0      http://www.moma.org/collection/works/2
# 1      http://www.moma.org/collection/works/4
# 2      http://www.moma.org/collection/works/6
# 3      http://www.moma.org/collection/works/7
# 4      http://www.moma.org/collection/works/8
# ...                                       ...
# 34149                                 missing
# 34150                                 missing
# 34151                                 missing
# 34152                                 missing
# 34153                                 missing
#
#                                             ThumbnailURL    1980
# 0      http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...  before
# 1      http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...  before
# 2      http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...  before
# 3      http://www.moma.org/media/W1siZiIsIjE0OCJdLFsi...  before
# 4      http://www.moma.org/media/W1siZiIsIjE0OSJdLFsi...  before
# ...                                                  ...     ...
# 34149                                            missing   after
# 34150                                            missing   after
# 34151                                            missing   after
# 34152                                            missing   after
# 34153                                            missing   after
#
# [134846 rows x 10 columns]

# %%
sns.catplot(x='1980', kind='count', data= moma_artworks_two_periods, order=['before', 'after'])

# %%
#count occurrences of department values before and after 1980
before_n = moma_before['Department'].value_counts().rename_axis('Department').reset_index(name='Before')
after_n = moma_after['Department'].value_counts().rename_axis('Department').reset_index(name='After')

moma_1980_x_dep = pd.merge(before_n, after_n, left_on='Department', right_on='Department')
moma_1980_x_dep
# Out:
#               Department  Before  After
# 0      Drawings & Prints   53181  21733
# 1            Photography   26398   5193
# 2  Architecture & Design   15624   3747
# 3   Painting & Sculpture    2980    920
# 4  Media and Performance     920   2004
# 5      Fluxus Collection     911    103
# 6                   Film     648    454

# %%
# create stacked bar chart with Panda
moma_1980_x_dep.plot(kind='bar', stacked=True,)
 
# labels for x & y axis
plt.xlabel('Departments')
plt.ylabel('')
 
# title of plot
plt.title('how the composition of the collectionchanges before and after 1980')
# Out:
# Text(0.5, 1.0, 'how the composition of the collectionchanges before and after 1980')

# %%
moma_1980_x_dep.set_index('Departments').plot(kind='bar', stacked=True, color=['steelblue', 'red'])
