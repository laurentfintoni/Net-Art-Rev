# %%
from __future__ import print_function
from bs4 import BeautifulSoup
import requests
import pandas as pd
path = '/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/Rhizome_data/'

# %%
#cleaned artists 
new_artists= pd.read_pickle(path+'MOMAartists.pkl')

# %%
moma_arch_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/architecture_design_cont.pkl')
moma_arch_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/architecture_design_mod.pkl')
moma_design_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/architecture_design_img_cont.pkl')
moma_design_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/architecture_design_img_mod.pkl')
moma_draw_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/draws_prints_cont.pkl')
moma_draw_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/draws_prints_mod.pkl')
moma_films_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/films_cont.pkl')
moma_films_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/films_mod.pkl')
moma_fluxus_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/fluxus_cont.pkl')
moma_fluxus_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/fluxus_mod.pkl')
moma_media_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/media_perf_cont.pkl')
moma_media_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/media_perf_mod.pkl')
moma_paint_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/paint_sculp_cont.pkl')
moma_paint_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/paint_sculp_mod.pkl')
moma_photo_cont = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/photo_cont.pkl')
moma_photo_mod = pd.read_pickle('/Users/laurentfintoni/Desktop/University/COURSE DOCS/YEAR 2/EPUB/PROJECT/EPDS/MOMA_data/pickle/departments/photo_mod.pkl')

# %%
def url_to_text_moma(url):
    if url != 'missing':
        page = requests.get(url)
        status = page.status_code
        if status != 404:
            soup = BeautifulSoup(page.content, "html.parser")
            if soup.find(class_="uneven-columns--work").find(class_='main-content') is not None:
                text = soup.find(class_="uneven-columns--work").find(class_='main-content').find_all('p')
            else:
                text = ''
        else:
            text = '404'
    else:
        text = 'missing'     
    print(url)
    return text

# %%
links = moma_arch_mod['URL'].to_list()

# %%
len(links)
# Out:
# 15624

# %%
arch_mod_1 = [url_to_text_moma(u) for u in links[0:5000]]
# Out:
# http://www.moma.org/collection/works/2
# http://www.moma.org/collection/works/4
# http://www.moma.org/collection/works/6
# http://www.moma.org/collection/works/7
# http://www.moma.org/collection/works/8
# http://www.moma.org/collection/works/9
# http://www.moma.org/collection/works/10
# http://www.moma.org/collection/works/11
# http://www.moma.org/collection/works/12
# http://www.moma.org/collection/works/13
# http://www.moma.org/collection/works/14
# http://www.moma.org/collection/works/15
# http://www.moma.org/collection/works/16
# http://www.moma.org/collection/works/17
# http://www.moma.org/collection/works/18
# http://www.moma.org/collection/works/19
# http://www.moma.org/collection/works/20
# http://www.moma.org/collection/works/21
# http://www.moma.org/collection/works/22
# http://www.moma.org/collection/works/23
# http://www.moma.org/collection/works/24
# http://www.moma.org/collection/works/25
# http://www.moma.org/collection/works/26
# ...
