# %% [markdown]
# **What we did until now:**
# 1. Download MoMA's data dumps of Artists and Artworks from their [GitHub repository](https://github.com/MuseumofModernArt/collection)
# 2. Download Rhizome's artists dataset, from thei [SPARQL endpoint](https://artbase.rhizome.org/wiki/Query) distinguishing between artists in Artbase and Artists bith in Artbase and wikidata
# 3. develope a filtering function to clean the MoMA's Artworks collection in order to narrow it and find artists similar to those ledgered in Rhizome and solve scalability problems between the two data sets

# %% [markdown]
# In the following chunck we have created

# %%
import re
import csv
import pandas as pd

path = './MoMA_data/'

import csv
with open(path+'Artworks.csv','r') as fin, open (path+'modern_artworks.csv','w') as modern, open (path+'cont_artworks.csv','w') as cont:

    m_writer = csv.writer(modern, delimiter=',' )
    c_writer = csv.writer(cont, delimiter=',' )
    m_writer.writerow(['Title','Artist','ConstituentID','ArtistBio','Nationality','BeginDate','EndDate','Gender','Date','Medium','Dimensions','CreditLine','AccessionNumber','Classification','Department','DateAcquired','Cataloged','ObjectID','URL','ThumbnailURL','Circumference (cm)','Depth (cm)','Diameter (cm)','Height (cm)','Length (cm)','Weight (kg)','Width (cm)','Seat Height (cm)','Duration (sec.)'])
    c_writer.writerow(['Title','Artist','ConstituentID','ArtistBio','Nationality','BeginDate','EndDate','Gender','Date','Medium','Dimensions','CreditLine','AccessionNumber','Classification','Department','DateAcquired','Cataloged','ObjectID','URL','ThumbnailURL','Circumference (cm)','Depth (cm)','Diameter (cm)','Height (cm)','Length (cm)','Weight (kg)','Width (cm)','Seat Height (cm)','Duration (sec.)'])


    for row in csv.reader(fin, delimiter=','):

        if str(row[8]) != "":
            if  re.match('.*\d\d\d\d.*', row[8]):
                year = re.findall(r'\d\d\d\d', row[8])
                if int(year[0]) < 1980:
                    m_writer.writerow(row) 
                else:
                    c_writer.writerow(row)

# %%
modern = pd.read_csv(path+'modern_artworks.csv')

modern = modern[['Title','Artist','ConstituentID','Date','Medium','Classification','Department','DateAcquired','URL','ThumbnailURL']]
modern.head()
# Out:
#                                                Title           Artist  \
# 0  Ferdinandsbrücke Project, Vienna, Austria (Ele...      Otto Wagner
# 1  Villa near Vienna Project, Outside Vienna, Aus...       Emil Hoppe
# 2  Villa, project, outside Vienna, Austria, Exter...       Emil Hoppe
# 3  The Manhattan Transcripts Project, New York, N...  Bernard Tschumi
# 4  The Manhattan Transcripts Project, New York, N...  Bernard Tschumi
#
#   ConstituentID     Date                                             Medium  \
# 0          6210     1896      Ink and cut-and-pasted painted pages on paper
# 1          7605     1903  Graphite, pen, color pencil, ink, and gouache ...
# 2          7605     1903  Graphite, color pencil, ink, and gouache on tr...
# 3          7056  1976-77                          Gelatin silver photograph
# 4          7056  1976-77                         Gelatin silver photographs
#
#   Classification             Department DateAcquired  \
# 0   Architecture  Architecture & Design   1996-04-09
# 1   Architecture  Architecture & Design   1997-01-15
# 2   Architecture  Architecture & Design   1997-01-15
# 3   Architecture  Architecture & Design   1995-01-17
# 4   Architecture  Architecture & Design   1995-01-17
#
#                                       URL  \
# 0  http://www.moma.org/collection/works/2
# 1  http://www.moma.org/collection/works/4
# 2  http://www.moma.org/collection/works/6
# 3  http://www.moma.org/collection/works/7
# 4  http://www.moma.org/collection/works/8
#
#                                         ThumbnailURL
# 0  http://www.moma.org/media/W1siZiIsIjU5NDA1Il0s...
# 1  http://www.moma.org/media/W1siZiIsIjk4Il0sWyJw...
# 2  http://www.moma.org/media/W1siZiIsIjEyNiJdLFsi...
# 3  http://www.moma.org/media/W1siZiIsIjE0OCJdLFsi...
# 4  http://www.moma.org/media/W1siZiIsIjE0OSJdLFsi...

# %%
contemporary = pd.read_csv(path+'cont_artworks.csv')
contemporary = contemporary[['Title','Artist','ConstituentID','Date','Medium','Classification','Department','DateAcquired','URL','ThumbnailURL']]
contemporary.head()
# Out:
#                                                Title  \
# 0  City of Music, National Superior Conservatory ...
# 1  The Manhattan Transcripts Project, New York, N...
# 2  The Manhattan Transcripts Project, New York, N...
# 3  The Manhattan Transcripts Project, New York, N...
# 4  The Manhattan Transcripts Project, New York, N...
#
#                      Artist ConstituentID  Date  \
# 0  Christian de Portzamparc          7470  1987
# 1           Bernard Tschumi          7056  1980
# 2           Bernard Tschumi          7056  1980
# 3           Bernard Tschumi          7056  1980
# 4           Bernard Tschumi          7056  1980
#
#                                               Medium Classification  \
# 0                  Paint and colored pencil on print   Architecture
# 1  Photographic reproduction with colored synthet...   Architecture
# 2  Photographic reproduction with colored synthet...   Architecture
# 3  Photographic reproduction with colored synthet...   Architecture
# 4                               Ink on tracing paper   Architecture
#
#               Department DateAcquired  \
# 0  Architecture & Design   1995-01-17
# 1  Architecture & Design   1995-01-17
# 2  Architecture & Design   1995-01-17
# 3  Architecture & Design   1995-01-17
# 4  Architecture & Design   1995-01-17
#
#                                        URL  \
# 0   http://www.moma.org/collection/works/3
# 1   http://www.moma.org/collection/works/5
# 2  http://www.moma.org/collection/works/33
# 3  http://www.moma.org/collection/works/38
# 4  http://www.moma.org/collection/works/44
#
#                                         ThumbnailURL
# 0  http://www.moma.org/media/W1siZiIsIjk3Il0sWyJw...
# 1  http://www.moma.org/media/W1siZiIsIjEyNCJdLFsi...
# 2  http://www.moma.org/media/W1siZiIsIjIwMCJdLFsi...
# 3  http://www.moma.org/media/W1siZiIsIjI2NyJdLFsi...
# 4  http://www.moma.org/media/W1siZiIsIjI5NiJdLFsi...

# %%
#create pickles for each dempartment in modern csv

architecture_design = modern[modern['Department'] == "Architecture & Design"]
architecture_design.to_pickle(f'./MoMA_data/pickle/architecture_design_mod.pkl')

architecture_design_img  = modern[modern['Department'] == "Architecture & Design - Image Archive"]
architecture_design_img.to_pickle(f'./MoMA_data/pickle/architecture_design_img_mod.pkl')

draws_prints= modern[modern['Department'] == "Drawings & Prints"]
draws_prints.to_pickle(f'./MoMA_data/pickle/draws_prints_mod.pkl')

films= modern[modern['Department'] == "Film"]
films.to_pickle(f'./MoMA_data/pickle/films_mod.pkl')

fluxus= modern[modern['Department'] == "Fluxus Collection"]
fluxus.to_pickle(f'./MoMA_data/pickle/fluxus_mod.pkl')

media_perf= modern[modern['Department'] == "Media and Performance"]
media_perf.to_pickle(f'./MoMA_data/pickle/media_perf_mod.pkl')

painting_sculp= modern[modern['Department'] == "Painting & Sculpture"]
painting_sculp.to_pickle(f'./MoMA_data/pickle/paint_sculp_mod.pkl')

photo= modern[modern['Department'] == "Photography"]
photo.to_pickle(f'./MoMA_data/pickle/photo_mod.pkl')


photo.head()
# Out:
#                                         Title        Artist ConstituentID  \
# 31603  Tuileries Sanglier / d'apres l'antique  Eugène Atget           229
# 31604                         Sapin (Trianon)  Eugène Atget           229
# 31605             Versailles, vase par Ballin  Eugène Atget           229
# 31606                                 Facteur  Eugène Atget           229
# 31607                             Chiffonnier  Eugène Atget           229
#
#             Date                                   Medium Classification  \
# 31603       1911                     Albumen silver print     Photograph
# 31604    1910-14                     Albumen silver print     Photograph
# 31605       1902               Matte albumen silver print     Photograph
# 31606  1899-1900  Gelatin silver printing-out-paper print     Photograph
# 31607  1899-1900                     Albumen silver print     Photograph
#
#         Department DateAcquired                                         URL  \
# 31603  Photography   1968-03-06  http://www.moma.org/collection/works/38879
# 31604  Photography   1968-03-06  http://www.moma.org/collection/works/38880
# 31605  Photography   1968-03-06  http://www.moma.org/collection/works/38881
# 31606  Photography   1968-03-06  http://www.moma.org/collection/works/38882
# 31607  Photography   1968-03-06  http://www.moma.org/collection/works/38883
#
#                                             ThumbnailURL
# 31603  http://www.moma.org/media/W1siZiIsIjMwMTMwNCJd...
# 31604  http://www.moma.org/media/W1siZiIsIjMxODEwMSJd...
# 31605  http://www.moma.org/media/W1siZiIsIjMxODEwMiJd...
# 31606  http://www.moma.org/media/W1siZiIsIjI4NjE4MiJd...
# 31607  http://www.moma.org/media/W1siZiIsIjI4NjE4MyJd...

# %%
architecture_design = contemporary[contemporary['Department'] == "Architecture & Design"]
architecture_design.to_pickle(f'./MoMA_data/pickle/architecture_design_cont.pkl')

architecture_design_img  = contemporary[contemporary['Department'] == "Architecture & Design - Image Archive"]
architecture_design_img.to_pickle(f'./MoMA_data/pickle/architecture_design_img_cont.pkl')

draws_prints= contemporary[contemporary['Department'] == "Drawings & Prints"]
draws_prints.to_pickle(f'./MoMA_data/pickle/draws_prints_cont.pkl')

films= contemporary[contemporary['Department'] == "Film"]
films.to_pickle(f'./MoMA_data/pickle/films_cont.pkl')

fluxus= contemporary[contemporary['Department'] == "Fluxus Collection"]
fluxus.to_pickle(f'./MoMA_data/pickle/fluxus_cont.pkl')

media_perf= contemporary[contemporary['Department'] == "Media and Performance"]
media_perf.to_pickle(f'./MoMA_data/pickle/media_perf_cont.pkl')

painting_sculp= contemporary[contemporary['Department'] == "Painting & Sculpture"]
painting_sculp.to_pickle(f'./MoMA_data/pickle/paint_sculp_cont.pkl')

photo= contemporary[contemporary['Department'] == "Photography"]
photo.to_pickle(f'./MoMA_data/pickle/photo_cont.pkl')


photo.head()
# Out:
#                Title          Artist ConstituentID  Date  \
# 4337        Untitled    Jim Bengston           473  1982
# 4338  Woman Twirling   Jo Ann Callis           928  1985
# 4339            Dusk    Peter Campus           944  1991
# 4340         Rupture    Peter Campus           944  1991
# 4341  Covered Wagons  James Casebere          6895  1985
#
#                                         Medium Classification   Department  \
# 4337                      Gelatin silver print     Photograph  Photography
# 4338                   Silver dye bleach print     Photograph  Photography
# 4339  Digital photograph; gelatin silver print     Photograph  Photography
# 4340  Digital photograph; gelatin silver print     Photograph  Photography
# 4341                      Gelatin silver print     Photograph  Photography
#
#      DateAcquired                                         URL  \
# 4337   1984-01-12                                         NaN
# 4338   1992-01-09  http://www.moma.org/collection/works/43871
# 4339   1992-01-09                                         NaN
# 4340   1992-01-09                                         NaN
# 4341   1992-01-09  http://www.moma.org/collection/works/43898
#
#                                            ThumbnailURL
# 4337                                                NaN
# 4338  http://www.moma.org/media/W1siZiIsIjk3MDQ4Il0s...
# 4339                                                NaN
# 4340                                                NaN
# 4341  http://www.moma.org/media/W1siZiIsIjEzNTQxNCJd...

# %%
artists= pd.read_csv('./MOMA_data/Artworks.csv')
artists.to_pickle(f'./MoMA_data/pickle/artists.pkl')

# %% [markdown]
# Follows an iteration over the clean df of MoMA's artworks in order to count the total number of artists annd insert them in a set

# %%
artists_list = set()

path = './MoMA_data/'

with open(path+'cleaned_artworks.csv','r') as myfile:
    for row in csv.reader(myfile, delimiter=','):
        if row[1] not in artists_list:
           artists_list.add(row[1])
    print(len(artists_list))
# Out:
# 1208

# %%
rhz_complete= pd.read_csv('./Rhizome_data/artists_complete.csv')

rhz_complete.head()
# Out:
#    ID              artistLabel                              artistPage  \
# 0 NaN                1010 1010  https://artbase.rhizome.org/wiki/Q1005
# 1 NaN                    11811  https://artbase.rhizome.org/wiki/Q4757
# 2 NaN                   220hex   https://artbase.rhizome.org/wiki/Q139
# 3 NaN                        6   https://artbase.rhizome.org/wiki/Q340
# 4 NaN  : O l g a : : M i n k :    https://artbase.rhizome.org/wiki/Q49
#
#   member of collective page  Nationality Gender  Birth  Death  Wiki QID  ULAN
# 0       NaN              NaN         NaN    NaN    NaN    NaN       NaN   NaN
# 1       NaN              NaN         NaN    NaN    NaN    NaN       NaN   NaN
# 2       NaN              NaN   Norwegian      M    NaN    NaN       NaN   NaN
# 3       NaN              NaN         NaN    NaN    NaN    NaN       NaN   NaN
# 4       NaN              NaN       Dutch      F    NaN    NaN       NaN   NaN
